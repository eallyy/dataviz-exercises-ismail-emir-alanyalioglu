# %% [markdown]
# # Lecture 2 — Class Exercise
# # Bar Charts: World Happiness Report 2025
#
# ---
#
# > **Your task:** Create **2 polished bar charts** using the World Happiness Report dataset.
# > **Push to:** `week02/lecture02_exercise.ipynb` in **your own GitHub repo** before the end of class.
#
# ---
#
# ### Rules (these will be checked in the model answer review next week)
# 1. Every bar chart **must have a zero baseline** — no exceptions (SWD p.51)
# 2. Every chart **must have an insight title**, not a topic title (SWD p.29)
# 3. Aim for **professional quality** — clean background, readable font, no clutter
# 4. Horizontal bars for long category names (SWD p.57)
#
# ---

# %% [markdown]
# ## Setup — Run this cell first

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/world_happiness_2025.csv')
df.columns = ['Country','Region','Happiness_Score','GDP','Social_Support',
              'Life_Expectancy','Freedom','Generosity','Corruption']

print(f"Dataset: {len(df)} countries, {len(df.columns)} columns")
print(df.head())
# Out:
# Dataset: 147 countries, 9 columns
#        Country          Region  Happiness_Score    GDP  Social_Support  \
# 0      Finland  Western Europe            7.736  1.749           1.783
# 1      Denmark  Western Europe            7.521  1.825           1.748
# 2      Iceland  Western Europe            7.515  1.799           1.840
# 3       Sweden  Western Europe            7.345  1.783           1.698
# 4  Netherlands  Western Europe            7.306  1.822           1.667
#
#    Life_Expectancy  Freedom  Generosity  Corruption
# 0            0.824    0.986       0.110       0.502
# 1            0.820    0.955       0.150       0.488
# 2            0.873    0.971       0.201       0.173
# 3            0.889    0.952       0.170       0.467
# 4            0.844    0.860       0.186       0.344

# %%
import plotly.express as px
import plotly.graph_objects as go

# Explore the dataset before you start
print("Regions in dataset:")
print(df['Region'].value_counts())
print("\nScore range:", df['Happiness_Score'].min(), "–", df['Happiness_Score'].max())
print("\nBottom 10 countries:")
print(df.nsmallest(10, 'Happiness_Score')[['Country','Region','Happiness_Score']])
# Out:
# Regions in dataset:
# Region
# Sub-Saharan Africa                    36
# Latin America and Caribbean           21
# Western Europe                        20
# Central and Eastern Europe            19
# Middle East and North Africa          18
# Southeast Asia                         9
# Commonwealth of Independent States     8
# East Asia                              6
# South Asia                             6
# North America and ANZ                  4
# Name: count, dtype: int64
#
# Score range: 1.364 – 7.736
#
# Bottom 10 countries:
#           Country                        Region  Happiness_Score
# 146   Afghanistan                    South Asia            1.364
# 145  Sierra Leone            Sub-Saharan Africa            2.998
# 144       Lebanon  Middle East and North Africa            3.188
# 143        Malawi            Sub-Saharan Africa            3.260
# 142      Zimbabwe            Sub-Saharan Africa            3.396
# 141      Botswana            Sub-Saharan Africa            3.438
# 140      DR Congo            Sub-Saharan Africa            3.469
# 139         Yemen  Middle East and North Africa            3.561
# 138       Comoros            Sub-Saharan Africa            3.754
# 137       Lesotho            Sub-Saharan Africa            3.757

# %% [markdown]
# ---
# ## Task 1 — Regional Comparison Bar Chart
#
# **What to build:** A horizontal bar chart showing the **average happiness score by region**, sorted from highest to lowest.
#
# **Requirements:**
# - Horizontal orientation (category names are long)
# - Sorted by score, descending (so the happiest region is at the top)
# - Zero baseline on x-axis
# - At least one design choice that goes beyond the Plotly default (colour, annotation, labels, etc.)
# - An insight title that answers: *which region stands out and why does it matter?*
#
# **Hint:** Use `df.groupby('Region')['Happiness_Score'].mean()` to compute the averages.

# %%
region_avg = (df.groupby('Region')['Happiness_Score']
              .mean()
              .reset_index()
              .sort_values('Happiness_Score'))

fig = px.bar(
    region_avg,
    x='Happiness_Score', y='Region',
    orientation='h',
    title='Western Europe scores nearly twice as high as Sub-Saharan Africa on happiness (2025)',
    labels={'Happiness_Score': 'Average Happiness Score', 'Region': ''},
    color_discrete_sequence=['#2E75B6']
)
fig.update_layout(
    xaxis=dict(range=[0, 8]),
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(family='Arial', size=13),
    xaxis_gridcolor='#EEEEEE',
    yaxis_gridcolor='white',
    showlegend=False,
    margin=dict(l=10, r=30, t=50, b=40),
    height=450
)
fig.update_traces(marker_line_width=0)
fig.show()

# %% [markdown]
# ---
# ## Task 2 — Bottom vs. Top: A Contrast Story
#
# **What to build:** A bar chart that highlights the **gap between the happiest and least happy countries**, focusing on a specific insight.
#
# **Requirements:**
# - Show the **top 8 AND bottom 8 countries** together (16 bars total)
# - Use **colour** to distinguish the two groups (not Plotly's default rainbow)
# - Add a **visual separator or annotation** that emphasises the gap
# - Insight title that tells the story of the gap
#
# **Hint:** Use `pd.concat([df.nlargest(8,'Happiness_Score'), df.nsmallest(8,'Happiness_Score')])` to get both groups.
#
# **Stretch goal:** Add a vertical reference line showing the global average.

# %%
top8 = df.nlargest(8, 'Happiness_Score').copy()
top8['Group'] = 'Top 8'
bottom8 = df.nsmallest(8, 'Happiness_Score').copy()
bottom8['Group'] = 'Bottom 8'

combined = pd.concat([bottom8, top8]).sort_values('Happiness_Score')
global_avg = df['Happiness_Score'].mean()

fig = px.bar(
    combined,
    x='Happiness_Score', y='Country',
    orientation='h',
    color='Group',
    color_discrete_map={'Top 8': '#2E75B6', 'Bottom 8': '#E63946'},
    title='The happiest countries score more than double the least happy — a 4.5-point gap (2025)',
    labels={'Happiness_Score': 'Happiness Score', 'Country': '', 'Group': ''},
    height=600
)
fig.add_vline(
    x=global_avg, line_dash='dash', line_color='#888888',
    annotation_text=f'Global avg: {global_avg:.1f}',
    annotation_position='top right',
    annotation_font_color='#888888'
)
fig.update_layout(
    xaxis=dict(range=[0, 8.5], gridcolor='#EEEEEE'),
    yaxis=dict(gridcolor='white'),
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(family='Arial', size=13),
    legend=dict(orientation='h', y=1.06),
    margin=dict(l=10, r=30, t=65, b=40)
)
fig.update_traces(marker_line_width=0)
fig.show()

# %% [markdown]
# ---
# ## Done? Stretch Goal
#
# If you finish both tasks with time to spare, try this:
#
# **Task 3 (stretch):** Build a **grouped bar chart** comparing 2 sub-factors (e.g. `GDP_per_capita` and `Freedom`) across the 5 most populated regions. Use colour meaningfully and write an insight title.
#
# Regions to include: `'Western Europe'`, `'Latin America'`, `'East Asia'`, `'Sub-Saharan Africa'`, `'South Asia'`

# %%
regions = ['Western Europe','Latin America and Caribbean','East Asia','Sub-Saharan Africa','South Asia']
sub = df[df['Region'].isin(regions)]
region_factors = (sub.groupby('Region')[['GDP','Freedom']]
                  .mean().reset_index()
                  .melt(id_vars='Region', value_vars=['GDP','Freedom']))

fig = px.bar(
    region_factors,
    x='value', y='Region',
    color='variable',
    orientation='h',
    barmode='group',
    title='Western Europe leads on GDP but Latin America rivals it on Freedom (2025)',
    labels={'value': 'Average Score', 'variable': '', 'Region': ''},
    color_discrete_map={'GDP': '#2E75B6', 'Freedom': '#70AD47'},
    height=400
)
fig.update_layout(
    xaxis=dict(range=[0, 2], gridcolor='#EEEEEE'),
    yaxis=dict(gridcolor='white'),
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(family='Arial', size=13),
    legend=dict(orientation='h', y=1.08),
    margin=dict(l=10, r=30, t=65, b=40)
)
fig.update_traces(marker_line_width=0)
fig.show()
